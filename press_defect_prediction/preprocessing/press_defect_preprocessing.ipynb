# %% [markdown]
# # 0. 준비 과정

# %%
# 1. 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터셋 압축 해제
# !unzip /content/drive/MyDrive/hole_dataset.ZIP -d /content/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/synthetic_data/train/segmentations/file_000006344.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006345.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006346.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006347.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006348.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006349.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006350.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006351.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006352.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006353.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006354.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006355.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006356.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006357.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006358.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006359.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006360.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006361.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006362.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006363.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006364.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006365.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006366.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006367.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006368.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006369.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006370.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006371.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006372.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006373.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006374.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006375.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006376.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006377.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006378.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006379.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006380.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006381.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006382.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006383.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006384.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006385.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006386.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006387.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006388.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006389.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006390.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006391.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006392.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006393.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006394.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006395.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006396.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006397.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006398.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006399.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006400.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006401.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006402.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006403.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006404.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006405.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006406.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006407.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006408.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006409.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006410.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006411.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006412.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006413.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006414.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006415.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006416.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006417.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006418.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006419.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006420.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006421.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006422.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006423.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006424.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006425.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006426.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006427.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006428.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006429.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006430.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006431.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006432.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006433.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006434.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006435.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006436.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006437.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006438.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006439.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006440.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006441.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006442.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006443.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006444.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006445.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006446.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006447.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006448.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006449.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006450.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006451.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006452.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006453.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006454.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006455.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006456.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006457.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006458.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006459.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006460.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006461.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006462.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006463.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006464.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006465.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006466.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006467.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006468.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006469.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006470.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006471.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006472.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006473.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006474.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006475.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006476.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006477.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006478.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006479.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006480.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006481.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006482.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006483.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006484.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006485.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006486.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006487.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006488.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006489.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006490.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006491.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006492.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006493.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006494.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006495.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006496.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006497.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006498.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006499.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006500.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006501.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006502.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006503.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006504.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006505.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006506.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006507.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006508.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006509.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006510.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006511.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006512.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006513.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006514.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006515.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006516.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006517.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006518.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006519.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006520.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006521.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006522.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006523.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006524.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006525.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006526.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006527.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006528.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006529.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006530.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006531.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006532.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006533.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006534.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006535.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006536.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006537.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006538.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006539.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006540.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006541.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006542.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006543.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006544.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006545.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006546.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006547.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006548.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006549.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006550.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006551.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006552.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006553.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006554.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006555.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006556.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006557.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006558.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006559.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006560.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006561.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006562.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006563.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006564.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006565.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006566.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006567.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006568.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006569.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006570.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006571.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006572.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006573.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006574.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006575.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006576.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006577.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006578.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006579.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006580.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006581.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006582.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006583.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006584.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006585.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006586.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006587.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006588.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006589.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006590.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006591.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006592.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006593.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006594.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006595.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006596.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006597.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006598.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006599.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006600.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006601.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006602.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006603.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006604.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006605.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006606.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006607.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006608.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006609.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006610.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006611.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006612.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006613.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006614.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006615.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006616.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006617.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006618.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006619.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006620.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006621.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006622.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006623.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006624.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006625.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006626.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006627.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006628.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006629.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006630.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006631.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006632.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006633.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006634.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006635.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006636.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006637.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006638.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006639.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006640.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006641.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006642.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006643.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006644.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006645.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006646.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006647.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006648.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006649.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006650.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006651.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006652.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006653.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006654.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006655.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006656.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006657.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006658.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006659.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006660.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006661.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006662.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006663.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006664.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006665.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006666.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006667.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006668.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006669.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006670.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006671.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006672.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006673.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006674.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006675.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006676.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006677.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006678.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006679.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006680.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006681.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006682.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006683.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006684.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006685.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006686.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006687.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006688.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006689.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006690.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006691.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006692.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006693.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006694.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006695.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006696.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006697.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006698.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006699.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006700.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006701.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006702.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006703.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006704.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006705.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006706.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006707.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006708.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006709.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006710.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006711.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006712.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006713.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006714.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006715.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006716.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006717.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006718.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006719.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006720.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006721.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006722.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006723.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006724.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006725.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006726.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006727.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006728.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006729.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006730.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006731.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006732.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006733.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006734.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006735.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006736.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006737.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006738.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006739.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006740.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006741.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006742.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006743.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006744.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006745.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006746.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006747.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006748.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006749.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006750.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006751.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006752.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006753.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006754.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006755.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006756.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006757.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006758.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006759.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006760.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006761.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006762.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006763.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006764.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006765.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006766.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006767.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006768.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006769.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006770.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006771.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006772.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006773.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006774.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006775.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006776.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006777.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006778.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006779.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006780.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006781.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006782.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006783.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006784.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006785.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006786.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006787.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006788.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006789.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006790.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006791.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006792.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006793.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006794.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006795.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006796.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006797.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006798.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006799.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006800.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006801.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006802.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006803.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006804.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006805.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006806.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006807.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006808.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006809.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006810.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006811.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006812.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006813.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006814.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006815.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006816.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006817.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006818.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006819.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006820.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006821.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006822.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006823.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006824.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006825.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006826.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006827.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006828.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006829.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006830.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006831.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006832.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006833.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006834.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006835.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006836.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006837.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006838.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006839.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006840.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006841.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006842.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006843.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006844.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006845.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006846.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006847.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006848.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006849.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006850.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006851.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006852.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006853.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006854.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006855.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006856.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006857.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006858.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006859.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006860.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006861.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006862.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006863.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006864.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006865.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006866.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006867.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006868.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006869.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006870.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006871.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006872.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006873.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006874.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006875.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006876.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006877.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006878.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006879.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006880.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006881.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006882.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006883.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006884.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006885.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006886.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006887.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006888.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006889.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006890.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006891.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006892.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006893.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006894.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006895.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006896.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006897.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006898.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006899.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006900.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006901.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006902.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006903.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006904.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006905.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006906.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006907.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006908.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006909.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006910.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006911.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006912.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006913.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006914.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006915.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006916.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006917.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006918.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006919.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006920.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006921.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006922.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006923.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006924.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006925.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006926.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006927.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006928.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006929.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006930.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006931.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006932.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006933.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006934.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006935.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006936.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006937.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006938.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006939.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006940.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006941.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006942.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006943.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006944.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006945.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006946.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006947.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006948.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006949.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006950.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006951.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006952.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006953.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006954.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006955.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006956.png
#   inflating: /content/synthetic_data/train/segmentations/file_000006957.png
# ...
#   inflating: /content/synthetic_data/valid/segmentations/file_000001475.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001476.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001477.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001478.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001479.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001480.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001481.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001482.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001483.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001484.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001485.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001486.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001487.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001488.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001489.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001490.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001491.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001492.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001493.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001494.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001495.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001496.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001497.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001498.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001499.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001500.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001501.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001502.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001503.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001504.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001505.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001506.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001507.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001508.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001509.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001510.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001511.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001512.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001513.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001514.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001515.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001516.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001517.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001518.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001519.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001520.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001521.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001522.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001523.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001524.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001525.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001526.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001527.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001528.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001529.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001530.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001531.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001532.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001533.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001534.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001535.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001536.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001537.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001538.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001539.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001540.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001541.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001542.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001543.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001544.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001545.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001546.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001547.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001548.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001549.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001550.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001551.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001552.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001553.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001554.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001555.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001556.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001557.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001558.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001559.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001560.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001561.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001562.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001563.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001564.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001565.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001566.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001567.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001568.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001569.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001570.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001571.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001572.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001573.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001574.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001575.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001576.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001577.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001578.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001579.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001580.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001581.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001582.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001583.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001584.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001585.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001586.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001587.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001588.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001589.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001590.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001591.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001592.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001593.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001594.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001595.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001596.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001597.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001598.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001599.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001600.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001601.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001602.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001603.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001604.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001605.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001606.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001607.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001608.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001609.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001610.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001611.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001612.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001613.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001614.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001615.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001616.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001617.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001618.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001619.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001620.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001621.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001622.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001623.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001624.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001625.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001626.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001627.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001628.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001629.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001630.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001631.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001632.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001633.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001634.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001635.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001636.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001637.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001638.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001639.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001640.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001641.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001642.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001643.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001644.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001645.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001646.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001647.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001648.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001649.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001650.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001651.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001652.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001653.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001654.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001655.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001656.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001657.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001658.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001659.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001660.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001661.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001662.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001663.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001664.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001665.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001666.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001667.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001668.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001669.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001670.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001671.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001672.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001673.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001674.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001675.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001676.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001677.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001678.png
#   inflating: /content/synthetic_data/valid/segmentations/file_000001679.png

# %% [markdown]
# # 1-1단계: 데이터 구조 파악 및 전처리
#
# - coco_segmentations.json 파일을 분석해서 각 inspection_id별로 어떤 이미지들이 있는지 매핑
# - 각 inspection_id별로 21장의 이미지가 모두 있는지 확인 (일부 inspection_id는 21장이 안 될 수도 있음)
#
# 1. 기본 데이터 구조: 총 이미지 수, 어노테이션 수, 카테고리 정보
# 2. Inspection ID 분석: 각 inspection_id별로 몇 장의 이미지가 있는지
# 3. 이미지 개수 분포: 21장을 가진 inspection_id가 몇 개인지, 그렇지 않은 것은 몇 개인지
# 4. 카메라-트리거 조합: 실제로 어떤 (cam_name, trigger_mm) 조합들이 존재하는지
# 5. 어노테이션 분석: 각 구멍 카테고리별로 얼마나 많은 어노테이션이 있는지, 마스킹된 것은 몇 개인지

# %%
import json
import pandas as pd
from collections import defaultdict, Counter

# 1. JSON 파일 로드
file_path = "/content/real_labeled_test_set_masked_images/coco_segmentations.json"

with open(file_path, 'r') as f:
    coco_data = json.load(f)

print("=== COCO 데이터셋 기본 정보 ===")
print(f"총 이미지 수: {len(coco_data['images'])}")
print(f"총 어노테이션 수: {len(coco_data['annotations'])}")
print(f"카테고리 수: {len(coco_data['categories'])}")

# 2. 카테고리 정보 확인
print("\n=== 카테고리 정보 ===")
for cat in coco_data['categories']:
    print(f"ID: {cat['id']}, Name: {cat['name']}")

# 3. inspection_id별 이미지 개수 분석
inspection_images = defaultdict(list)
cam_trigger_combinations = set()

for img in coco_data['images']:
    inspection_id = img['inspection_id']
    cam_name = img['cam_name']
    trigger_mm = img['trigger_mm']

    inspection_images[inspection_id].append({
        'image_id': img['id'],
        'file_name': img['file_name'],
        'cam_name': cam_name,
        'trigger_mm': trigger_mm
    })

    cam_trigger_combinations.add((cam_name, trigger_mm))

print(f"\n=== Inspection ID 분석 ===")
print(f"총 inspection_id 개수: {len(inspection_images)}")
print(f"inspection_id 범위: {min(inspection_images.keys())} ~ {max(inspection_images.keys())}")

# 4. 각 inspection_id별 이미지 개수 분포
image_counts = [len(images) for images in inspection_images.values()]
image_count_distribution = Counter(image_counts)

print(f"\n=== Inspection ID별 이미지 개수 분포 ===")
for count, frequency in sorted(image_count_distribution.items()):
    print(f"{count}장: {frequency}개 inspection_id")

# 5. 카메라-트리거 조합 분석
print(f"\n=== 카메라-트리거 조합 분석 ===")
print(f"총 (cam_name, trigger_mm) 조합 수: {len(cam_trigger_combinations)}")
print("가능한 조합들:")
for cam, trigger in sorted(cam_trigger_combinations):
    print(f"  {cam} - {trigger}mm")

# 6. 상세 분석: 각 inspection_id가 어떤 조합을 가지고 있는지
print(f"\n=== 각 Inspection ID별 상세 정보 (처음 5개) ===")
for inspection_id in sorted(list(inspection_images.keys()))[:5]:
    images = inspection_images[inspection_id]
    print(f"\nInspection ID {inspection_id}: {len(images)}장")
    for img in images:
        print(f"  - {img['file_name']}: {img['cam_name']}, {img['trigger_mm']}mm")

# 7. 21장이 아닌 inspection_id 찾기
print(f"\n=== 21장이 아닌 Inspection ID들 ===")
non_21_inspections = []
for inspection_id, images in inspection_images.items():
    if len(images) != 21:
        non_21_inspections.append((inspection_id, len(images)))

if non_21_inspections:
    print("21장이 아닌 inspection_id:")
    for inspection_id, count in sorted(non_21_inspections):
        print(f"  Inspection ID {inspection_id}: {count}장")
else:
    print("모든 inspection_id가 21장씩 가지고 있습니다.")

# 8. 어노테이션 분석 (구멍 탐지 정보)
print(f"\n=== 어노테이션 분석 ===")
category_counts = Counter()
masked_counts = Counter()

for ann in coco_data['annotations']:
    category_counts[ann['category_id']] += 1
    if ann.get('is_masked', 0) == 1:
        masked_counts[ann['category_id']] += 1

print("카테고리별 어노테이션 개수:")
for cat in coco_data['categories']:
    cat_id = cat['id']
    cat_name = cat['name']
    total = category_counts[cat_id]
    masked = masked_counts[cat_id]
    print(f"  {cat_name} (ID:{cat_id}): 총 {total}개, 마스킹된 것 {masked}개")

# 9. 데이터 구조를 DataFrame으로 정리
inspection_summary = []
for inspection_id, images in inspection_images.items():
    inspection_summary.append({
        'inspection_id': inspection_id,
        'image_count': len(images),
        'cam_trigger_combinations': len(set((img['cam_name'], img['trigger_mm']) for img in images))
    })

df_summary = pd.DataFrame(inspection_summary)
print(f"\n=== 요약 통계 ===")
print(f"평균 이미지 수: {df_summary['image_count'].mean():.2f}")
print(f"최소 이미지 수: {df_summary['image_count'].min()}")
print(f"최대 이미지 수: {df_summary['image_count'].max()}")
print(f"평균 카메라-트리거 조합 수: {df_summary['cam_trigger_combinations'].mean():.2f}")
# Out:
# === COCO 데이터셋 기본 정보 ===
# 총 이미지 수: 1680
# 총 어노테이션 수: 6697
# 카테고리 수: 7
#
# === 카테고리 정보 ===
# ID: 0, Name: AX1
# ID: 1, Name: BY1
# ID: 2, Name: CY1
# ID: 3, Name: DY1
# ID: 4, Name: DY2
# ID: 5, Name: DY3
# ID: 6, Name: DY4
#
# === Inspection ID 분석 ===
# 총 inspection_id 개수: 86
# inspection_id 범위: 1 ~ 86
#
# === Inspection ID별 이미지 개수 분포 ===
# 3장: 1개 inspection_id
# 4장: 1개 inspection_id
# 6장: 2개 inspection_id
# 9장: 2개 inspection_id
# 12장: 2개 inspection_id
# 15장: 2개 inspection_id
# 17장: 1개 inspection_id
# 18장: 1개 inspection_id
# 21장: 74개 inspection_id
#
# === 카메라-트리거 조합 분석 ===
# 총 (cam_name, trigger_mm) 조합 수: 21
# 가능한 조합들:
#   Z1CAM02 - 700mm
#   Z1CAM02 - 1200mm
#   Z1CAM02 - 1700mm
#   Z1CAM03 - 1200mm
#   Z1CAM04 - 1700mm
#   Z1CAM04 - 1800mm
#   Z1CAM05 - 700mm
#   Z1CAM05 - 1100mm
#   Z1CAM05 - 1200mm
#   Z1CAM05 - 1300mm
#   Z1CAM06 - 1200mm
#   Z1CAM06 - 1300mm
#   Z1CAM06 - 1700mm
#   Z1CAM07 - 700mm
#   Z1CAM07 - 800mm
#   Z1CAM07 - 1100mm
#   Z1CAM07 - 1200mm
#   Z1CAM08 - 1200mm
#   Z1CAM08 - 1300mm
#   Z1CAM08 - 1500mm
#   Z1CAM08 - 1700mm
#
# === 각 Inspection ID별 상세 정보 (처음 5개) ===
#
# Inspection ID 1: 21장
#   - file_0001.jpg: Z1CAM02, 700mm
#   - file_0081.jpg: Z1CAM02, 1200mm
#   - file_0161.jpg: Z1CAM02, 1700mm
#   - file_0241.jpg: Z1CAM03, 1200mm
#   - file_0321.jpg: Z1CAM04, 1700mm
#   - file_0401.jpg: Z1CAM04, 1800mm
#   - file_0481.jpg: Z1CAM05, 700mm
#   - file_0561.jpg: Z1CAM05, 1100mm
#   - file_0641.jpg: Z1CAM05, 1200mm
#   - file_0721.jpg: Z1CAM05, 1300mm
#   - file_0801.jpg: Z1CAM06, 1200mm
#   - file_0881.jpg: Z1CAM06, 1300mm
#   - file_0961.jpg: Z1CAM06, 1700mm
#   - file_1041.jpg: Z1CAM07, 700mm
#   - file_1121.jpg: Z1CAM07, 800mm
#   - file_1201.jpg: Z1CAM07, 1100mm
#   - file_1281.jpg: Z1CAM07, 1200mm
#   - file_1361.jpg: Z1CAM08, 1200mm
#   - file_1441.jpg: Z1CAM08, 1300mm
#   - file_1521.jpg: Z1CAM08, 1500mm
#   - file_1601.jpg: Z1CAM08, 1700mm
#
# Inspection ID 2: 21장
#   - file_0002.jpg: Z1CAM02, 700mm
#   - file_0082.jpg: Z1CAM02, 1200mm
#   - file_0162.jpg: Z1CAM02, 1700mm
#   - file_0242.jpg: Z1CAM03, 1200mm
#   - file_0322.jpg: Z1CAM04, 1700mm
#   - file_0402.jpg: Z1CAM04, 1800mm
#   - file_0482.jpg: Z1CAM05, 700mm
#   - file_0562.jpg: Z1CAM05, 1100mm
#   - file_0642.jpg: Z1CAM05, 1200mm
#   - file_0722.jpg: Z1CAM05, 1300mm
#   - file_0802.jpg: Z1CAM06, 1200mm
#   - file_0882.jpg: Z1CAM06, 1300mm
#   - file_0962.jpg: Z1CAM06, 1700mm
#   - file_1042.jpg: Z1CAM07, 700mm
#   - file_1122.jpg: Z1CAM07, 800mm
#   - file_1202.jpg: Z1CAM07, 1100mm
#   - file_1282.jpg: Z1CAM07, 1200mm
#   - file_1362.jpg: Z1CAM08, 1200mm
#   - file_1442.jpg: Z1CAM08, 1300mm
#   - file_1522.jpg: Z1CAM08, 1500mm
#   - file_1602.jpg: Z1CAM08, 1700mm
#
# Inspection ID 3: 21장
#   - file_0003.jpg: Z1CAM02, 700mm
#   - file_0083.jpg: Z1CAM02, 1200mm
#   - file_0163.jpg: Z1CAM02, 1700mm
#   - file_0243.jpg: Z1CAM03, 1200mm
#   - file_0323.jpg: Z1CAM04, 1700mm
#   - file_0403.jpg: Z1CAM04, 1800mm
#   - file_0483.jpg: Z1CAM05, 700mm
#   - file_0563.jpg: Z1CAM05, 1100mm
#   - file_0643.jpg: Z1CAM05, 1200mm
#   - file_0723.jpg: Z1CAM05, 1300mm
#   - file_0803.jpg: Z1CAM06, 1200mm
#   - file_0883.jpg: Z1CAM06, 1300mm
#   - file_0963.jpg: Z1CAM06, 1700mm
#   - file_1043.jpg: Z1CAM07, 700mm
#   - file_1123.jpg: Z1CAM07, 800mm
#   - file_1203.jpg: Z1CAM07, 1100mm
#   - file_1283.jpg: Z1CAM07, 1200mm
#   - file_1363.jpg: Z1CAM08, 1200mm
#   - file_1443.jpg: Z1CAM08, 1300mm
#   - file_1523.jpg: Z1CAM08, 1500mm
#   - file_1603.jpg: Z1CAM08, 1700mm
#
# Inspection ID 4: 21장
#   - file_0004.jpg: Z1CAM02, 700mm
#   - file_0084.jpg: Z1CAM02, 1200mm
#   - file_0164.jpg: Z1CAM02, 1700mm
#   - file_0244.jpg: Z1CAM03, 1200mm
#   - file_0324.jpg: Z1CAM04, 1700mm
#   - file_0404.jpg: Z1CAM04, 1800mm
#   - file_0484.jpg: Z1CAM05, 700mm
#   - file_0564.jpg: Z1CAM05, 1100mm
#   - file_0644.jpg: Z1CAM05, 1200mm
#   - file_0724.jpg: Z1CAM05, 1300mm
#   - file_0804.jpg: Z1CAM06, 1200mm
#   - file_0884.jpg: Z1CAM06, 1300mm
#   - file_0964.jpg: Z1CAM06, 1700mm
#   - file_1044.jpg: Z1CAM07, 700mm
#   - file_1124.jpg: Z1CAM07, 800mm
#   - file_1204.jpg: Z1CAM07, 1100mm
#   - file_1284.jpg: Z1CAM07, 1200mm
#   - file_1364.jpg: Z1CAM08, 1200mm
#   - file_1444.jpg: Z1CAM08, 1300mm
#   - file_1524.jpg: Z1CAM08, 1500mm
#   - file_1604.jpg: Z1CAM08, 1700mm
#
# Inspection ID 5: 21장
#   - file_0005.jpg: Z1CAM02, 700mm
#   - file_0085.jpg: Z1CAM02, 1200mm
#   - file_0165.jpg: Z1CAM02, 1700mm
#   - file_0245.jpg: Z1CAM03, 1200mm
#   - file_0325.jpg: Z1CAM04, 1700mm
#   - file_0405.jpg: Z1CAM04, 1800mm
#   - file_0485.jpg: Z1CAM05, 700mm
#   - file_0565.jpg: Z1CAM05, 1100mm
#   - file_0645.jpg: Z1CAM05, 1200mm
#   - file_0725.jpg: Z1CAM05, 1300mm
#   - file_0805.jpg: Z1CAM06, 1200mm
#   - file_0885.jpg: Z1CAM06, 1300mm
#   - file_0965.jpg: Z1CAM06, 1700mm
#   - file_1045.jpg: Z1CAM07, 700mm
#   - file_1125.jpg: Z1CAM07, 800mm
#   - file_1205.jpg: Z1CAM07, 1100mm
#   - file_1285.jpg: Z1CAM07, 1200mm
#   - file_1365.jpg: Z1CAM08, 1200mm
#   - file_1445.jpg: Z1CAM08, 1300mm
#   - file_1525.jpg: Z1CAM08, 1500mm
#   - file_1605.jpg: Z1CAM08, 1700mm
#
# === 21장이 아닌 Inspection ID들 ===
# 21장이 아닌 inspection_id:
#   Inspection ID 12: 3장
#   Inspection ID 13: 4장
#   Inspection ID 27: 12장
#   Inspection ID 41: 15장
#   Inspection ID 65: 15장
#   Inspection ID 80: 12장
#   Inspection ID 81: 18장
#   Inspection ID 82: 17장
#   Inspection ID 83: 9장
#   Inspection ID 84: 9장
#   Inspection ID 85: 6장
#   Inspection ID 86: 6장
#
# === 어노테이션 분석 ===
# 카테고리별 어노테이션 개수:
#   AX1 (ID:0): 총 354개, 마스킹된 것 29개
#   BY1 (ID:1): 총 1467개, 마스킹된 것 148개
#   CY1 (ID:2): 총 630개, 마스킹된 것 62개
#   DY1 (ID:3): 총 1073개, 마스킹된 것 107개
#   DY2 (ID:4): 총 1280개, 마스킹된 것 136개
#   DY3 (ID:5): 총 846개, 마스킹된 것 80개
#   DY4 (ID:6): 총 1047개, 마스킹된 것 103개
#
# === 요약 통계 ===
# 평균 이미지 수: 19.53
# 최소 이미지 수: 3
# 최대 이미지 수: 21
# 평균 카메라-트리거 조합 수: 19.53

# %% [markdown]
# ### 📌 완전한 데이터(21장의 이미지)를 가진 inspection_id
# - 74개의 inspection_id가 21장씩 완전한 데이터 보유
# - 12개의 inspection_id가 3~18장으로 불완전한 데이터 (12, 13, 27, 41, 65, 80, 81, 82, 83, 84, 85, 86)
#
# ### 📌어노테이션 분포
# - 총 6,697개의 구멍 어노테이션
# - BY1, DY1, DY2가 가장 많이 탐지됨 (1,000개 이상)
# - AX1이 가장 적게 탐지됨 (354개)
# - 전체 어노테이션의 약 10.5%가 마스킹됨 (결함 시뮬레이션용)

# %% [markdown]
# # 1-2단계: 추가 분석
# 1️⃣ 각 inspection_id별 7개 카테고리 존재 여부
# - 마스킹되지 않은 어노테이션만 "존재하는" 카테고리로 간주
# - 완전한 데이터(21장)를 가진 inspection_id들에 대해서만 분석
# - 정상품 vs 결함품 구분
#
# 2️⃣ 21장 미만 inspection_id 처리 방침
# 동의합니다! 21장 미만의 inspection_id들은 분석에서 제외하는 것이 맞습니다. 이유:
#
# - 모든 각도/거리에서 촬영되지 않아 구멍 탐지가 불완전할 수 있음
# - 실제 생산 환경에서도 모든 카메라-트리거 조합에서 촬영이 필요
# - 품질 관리의 일관성을 위해 완전한 데이터만 사용해야 함
#
# 3️⃣ 마스킹 분포 분석
#
# - 어떤 inspection_id에서 어떤 카테고리가 마스킹되었는지 상세 분석
# - 마스킹 = 결함 시뮬레이션 (구멍이 뚫리지 않은 상황)
# - 카테고리별 마스킹 빈도 통계

# %%
import json
import pandas as pd
from collections import defaultdict, Counter

# JSON 파일 로드
file_path = "/content/real_labeled_test_set_masked_images/coco_segmentations.json"

with open(file_path, 'r') as f:
    coco_data = json.load(f)

# image_id와 inspection_id 매핑 생성
image_to_inspection = {}
for img in coco_data['images']:
    image_to_inspection[img['id']] = img['inspection_id']

# 카테고리 이름 매핑
category_names = {cat['id']: cat['name'] for cat in coco_data['categories']}
all_categories = set(category_names.keys())  # {0, 1, 2, 3, 4, 5, 6}

print("=== 1. 각 inspection_id별로 7개 카테고리 존재 여부 확인 ===")

# inspection_id별 카테고리 존재 여부 분석
inspection_categories = defaultdict(set)
inspection_masked_categories = defaultdict(set)

for ann in coco_data['annotations']:
    image_id = ann['image_id']
    inspection_id = image_to_inspection[image_id]
    category_id = ann['category_id']
    is_masked = ann.get('is_masked', 0)

    # 마스킹되지 않은 경우만 "존재하는" 카테고리로 간주
    if is_masked == 0:
        inspection_categories[inspection_id].add(category_id)
    else:
        inspection_masked_categories[inspection_id].add(category_id)

# 완전한 데이터를 가진 inspection_id들 (21장)
complete_inspections = []
incomplete_inspections = []

inspection_images = defaultdict(list)
for img in coco_data['images']:
    inspection_images[img['inspection_id']].append(img)

for inspection_id, images in inspection_images.items():
    if len(images) == 21:
        complete_inspections.append(inspection_id)
    else:
        incomplete_inspections.append(inspection_id)

print(f"완전한 데이터 (21장): {len(complete_inspections)}개")
print(f"불완전한 데이터 (21장 미만): {len(incomplete_inspections)}개")

# 완전한 데이터에서 카테고리 분석
print(f"\n=== 완전한 데이터 (21장) inspection_id들의 카테고리 분석 ===")

perfect_inspections = []  # 7개 카테고리 모두 존재
defective_inspections = []  # 일부 카테고리 누락 (결함품)

category_analysis = []

for inspection_id in sorted(complete_inspections):
    existing_categories = inspection_categories[inspection_id]
    masked_categories = inspection_masked_categories[inspection_id]
    missing_categories = all_categories - existing_categories

    category_analysis.append({
        'inspection_id': inspection_id,
        'existing_count': len(existing_categories),
        'missing_count': len(missing_categories),
        'masked_count': len(masked_categories),
        'existing_categories': sorted(list(existing_categories)),
        'missing_categories': sorted(list(missing_categories)),
        'masked_categories': sorted(list(masked_categories))
    })

    if len(existing_categories) == 7:
        perfect_inspections.append(inspection_id)
    else:
        defective_inspections.append(inspection_id)

print(f"완벽한 제품 (7개 카테고리 모두 존재): {len(perfect_inspections)}개")
print(f"결함 제품 (일부 카테고리 누락): {len(defective_inspections)}개")

# 상세 결과 출력
print(f"\n=== 결함 제품 상세 분석 ===")
for analysis in category_analysis:
    if analysis['missing_count'] > 0:
        inspection_id = analysis['inspection_id']
        existing = [category_names[cat_id] for cat_id in analysis['existing_categories']]
        missing = [category_names[cat_id] for cat_id in analysis['missing_categories']]
        masked = [category_names[cat_id] for cat_id in analysis['masked_categories']]

        print(f"\nInspection ID {inspection_id}:")
        print(f"  존재하는 구멍 ({len(existing)}개): {existing}")
        print(f"  누락된 구멍 ({len(missing)}개): {missing}")
        if masked:
            print(f"  마스킹된 구멍 ({len(masked)}개): {masked}")

print(f"\n=== 3. 마스킹된 어노테이션 분포 분석 ===")

# 마스킹 통계
masking_stats = defaultdict(lambda: defaultdict(int))
total_masking_by_inspection = defaultdict(int)

for ann in coco_data['annotations']:
    if ann.get('is_masked', 0) == 1:
        image_id = ann['image_id']
        inspection_id = image_to_inspection[image_id]
        category_id = ann['category_id']

        masking_stats[inspection_id][category_id] += 1
        total_masking_by_inspection[inspection_id] += 1

print(f"마스킹이 적용된 inspection_id 개수: {len(masking_stats)}")

# 마스킹된 inspection_id들과 카테고리별 분포
print(f"\n=== 마스킹된 inspection_id별 상세 분석 ===")
for inspection_id in sorted(masking_stats.keys()):
    if inspection_id in complete_inspections:  # 완전한 데이터만 분석
        print(f"\nInspection ID {inspection_id} (총 마스킹 수: {total_masking_by_inspection[inspection_id]}):")
        for category_id, count in sorted(masking_stats[inspection_id].items()):
            category_name = category_names[category_id]
            print(f"  {category_name}: {count}개 마스킹")

# 마스킹 통계 요약
print(f"\n=== 마스킹 통계 요약 ===")
masked_inspection_ids = [iid for iid in masking_stats.keys() if iid in complete_inspections]
print(f"완전한 데이터 중 마스킹이 적용된 inspection_id: {len(masked_inspection_ids)}개")
print(f"마스킹이 적용되지 않은 inspection_id: {len(complete_inspections) - len(masked_inspection_ids)}개")

# 카테고리별 마스킹 빈도
category_masking_freq = Counter()
for inspection_id, categories in masking_stats.items():
    if inspection_id in complete_inspections:
        for category_id in categories.keys():
            category_masking_freq[category_id] += 1

print(f"\n카테고리별 마스킹 적용된 inspection_id 수:")
for category_id in sorted(category_masking_freq.keys()):
    category_name = category_names[category_id]
    freq = category_masking_freq[category_id]
    print(f"  {category_name}: {freq}개 inspection_id에서 마스킹")

# 최종 요약
print(f"\n=== 최종 요약 ===")
print(f"전체 inspection_id: {len(inspection_images)}개")
print(f"  - 완전한 데이터 (21장): {len(complete_inspections)}개")
print(f"    - 정상품 (7개 구멍 모두 존재): {len(perfect_inspections)}개")
print(f"    - 결함품 (일부 구멍 누락): {len(defective_inspections)}개")
print(f"  - 불완전한 데이터 (21장 미만): {len(incomplete_inspections)}개 → 분석 제외 권장")

# DataFrame으로 정리하여 CSV 저장 가능하도록 준비
df_analysis = pd.DataFrame(category_analysis)
print(f"\n완전한 데이터 inspection_id들의 통계:")
print(f"존재하는 카테고리 수 분포:")
print(df_analysis['existing_count'].value_counts().sort_index())
# Out:
# === 1. 각 inspection_id별로 7개 카테고리 존재 여부 확인 ===
# 완전한 데이터 (21장): 74개
# 불완전한 데이터 (21장 미만): 12개
#
# === 완전한 데이터 (21장) inspection_id들의 카테고리 분석 ===
# 완벽한 제품 (7개 카테고리 모두 존재): 74개
# 결함 제품 (일부 카테고리 누락): 0개
#
# === 결함 제품 상세 분석 ===
#
# === 3. 마스킹된 어노테이션 분포 분석 ===
# 마스킹이 적용된 inspection_id 개수: 79
#
# === 마스킹된 inspection_id별 상세 분석 ===
#
# Inspection ID 1 (총 마스킹 수: 11):
#   BY1: 4개 마스킹
#   DY1: 1개 마스킹
#   DY2: 5개 마스킹
#   DY3: 1개 마스킹
#
# Inspection ID 2 (총 마스킹 수: 6):
#   AX1: 1개 마스킹
#   BY1: 3개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 3 (총 마스킹 수: 11):
#   AX1: 1개 마스킹
#   BY1: 1개 마스킹
#   DY1: 3개 마스킹
#   DY2: 5개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 4 (총 마스킹 수: 9):
#   BY1: 3개 마스킹
#   CY1: 1개 마스킹
#   DY1: 2개 마스킹
#   DY3: 3개 마스킹
#
# Inspection ID 5 (총 마스킹 수: 5):
#   BY1: 2개 마스킹
#   DY2: 3개 마스킹
#
# Inspection ID 6 (총 마스킹 수: 9):
#   BY1: 2개 마스킹
#   DY1: 3개 마스킹
#   DY2: 2개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 7 (총 마스킹 수: 10):
#   AX1: 1개 마스킹
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#   DY2: 2개 마스킹
#   DY3: 2개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 8 (총 마스킹 수: 7):
#   AX1: 3개 마스킹
#   CY1: 1개 마스킹
#   DY3: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 9 (총 마스킹 수: 9):
#   BY1: 3개 마스킹
#   DY1: 1개 마스킹
#   DY2: 3개 마스킹
#   DY3: 2개 마스킹
#
# Inspection ID 10 (총 마스킹 수: 16):
#   BY1: 2개 마스킹
#   CY1: 2개 마스킹
#   DY1: 2개 마스킹
#   DY2: 4개 마스킹
#   DY3: 1개 마스킹
#   DY4: 5개 마스킹
#
# Inspection ID 11 (총 마스킹 수: 8):
#   BY1: 2개 마스킹
#   DY1: 4개 마스킹
#   DY2: 2개 마스킹
#
# Inspection ID 14 (총 마스킹 수: 11):
#   AX1: 1개 마스킹
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY1: 4개 마스킹
#   DY2: 2개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 15 (총 마스킹 수: 11):
#   AX1: 2개 마스킹
#   BY1: 4개 마스킹
#   CY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 16 (총 마스킹 수: 8):
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#   DY1: 2개 마스킹
#   DY2: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 17 (총 마스킹 수: 8):
#   BY1: 1개 마스킹
#   CY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY3: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 18 (총 마스킹 수: 7):
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY1: 3개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 19 (총 마스킹 수: 10):
#   AX1: 2개 마스킹
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 3개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 20 (총 마스킹 수: 7):
#   DY1: 3개 마스킹
#   DY2: 1개 마스킹
#   DY3: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 21 (총 마스킹 수: 17):
#   AX1: 2개 마스킹
#   BY1: 3개 마스킹
#   CY1: 2개 마스킹
#   DY1: 2개 마스킹
#   DY2: 3개 마스킹
#   DY3: 1개 마스킹
#   DY4: 4개 마스킹
#
# Inspection ID 22 (총 마스킹 수: 9):
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY1: 2개 마스킹
#   DY2: 1개 마스킹
#   DY3: 1개 마스킹
#   DY4: 3개 마스킹
#
# Inspection ID 23 (총 마스킹 수: 5):
#   AX1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 24 (총 마스킹 수: 12):
#   BY1: 1개 마스킹
#   CY1: 2개 마스킹
#   DY1: 3개 마스킹
#   DY2: 2개 마스킹
#   DY3: 3개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 25 (총 마스킹 수: 5):
#   DY1: 1개 마스킹
#   DY2: 2개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 26 (총 마스킹 수: 12):
#   BY1: 5개 마스킹
#   CY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY3: 3개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 28 (총 마스킹 수: 12):
#   BY1: 4개 마스킹
#   CY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY3: 2개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 29 (총 마스킹 수: 7):
#   AX1: 1개 마스킹
#   BY1: 1개 마스킹
#   CY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 30 (총 마스킹 수: 4):
#   BY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 31 (총 마스킹 수: 7):
#   AX1: 1개 마스킹
#   BY1: 1개 마스킹
#   CY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 32 (총 마스킹 수: 9):
#   BY1: 5개 마스킹
#   DY2: 2개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 33 (총 마스킹 수: 6):
#   DY1: 1개 마스킹
#   DY2: 3개 마스킹
#   DY3: 2개 마스킹
#
# Inspection ID 34 (총 마스킹 수: 14):
#   AX1: 1개 마스킹
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 6개 마스킹
#   DY4: 3개 마스킹
#
# Inspection ID 35 (총 마스킹 수: 9):
#   BY1: 1개 마스킹
#   DY2: 4개 마스킹
#   DY3: 2개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 36 (총 마스킹 수: 18):
#   AX1: 1개 마스킹
#   BY1: 6개 마스킹
#   CY1: 2개 마스킹
#   DY1: 2개 마스킹
#   DY2: 3개 마스킹
#   DY3: 1개 마스킹
#   DY4: 3개 마스킹
#
# Inspection ID 37 (총 마스킹 수: 8):
#   BY1: 2개 마스킹
#   DY1: 3개 마스킹
#   DY2: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 38 (총 마스킹 수: 8):
#   CY1: 1개 마스킹
#   DY1: 3개 마스킹
#   DY2: 2개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 39 (총 마스킹 수: 6):
#   BY1: 3개 마스킹
#   DY2: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 40 (총 마스킹 수: 3):
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#
# Inspection ID 42 (총 마스킹 수: 4):
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#
# Inspection ID 43 (총 마스킹 수: 5):
#   BY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 44 (총 마스킹 수: 6):
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY2: 2개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 45 (총 마스킹 수: 7):
#   BY1: 1개 마스킹
#   CY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY3: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 46 (총 마스킹 수: 14):
#   AX1: 1개 마스킹
#   BY1: 3개 마스킹
#   CY1: 2개 마스킹
#   DY1: 2개 마스킹
#   DY2: 3개 마스킹
#   DY3: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 47 (총 마스킹 수: 7):
#   BY1: 1개 마스킹
#   DY1: 4개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 48 (총 마스킹 수: 8):
#   AX1: 1개 마스킹
#   DY1: 2개 마스킹
#   DY2: 1개 마스킹
#   DY3: 3개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 49 (총 마스킹 수: 13):
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#   DY1: 2개 마스킹
#   DY2: 5개 마스킹
#   DY3: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 50 (총 마스킹 수: 11):
#   AX1: 1개 마스킹
#   BY1: 4개 마스킹
#   DY2: 1개 마스킹
#   DY3: 2개 마스킹
#   DY4: 3개 마스킹
#
# Inspection ID 51 (총 마스킹 수: 11):
#   BY1: 3개 마스킹
#   CY1: 1개 마스킹
#   DY2: 3개 마스킹
#   DY3: 1개 마스킹
#   DY4: 3개 마스킹
#
# Inspection ID 52 (총 마스킹 수: 7):
#   AX1: 1개 마스킹
#   BY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY3: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 53 (총 마스킹 수: 11):
#   AX1: 2개 마스킹
#   BY1: 5개 마스킹
#   DY1: 1개 마스킹
#   DY3: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 54 (총 마스킹 수: 9):
#   BY1: 3개 마스킹
#   CY1: 1개 마스킹
#   DY1: 2개 마스킹
#   DY2: 2개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 55 (총 마스킹 수: 8):
#   BY1: 3개 마스킹
#   CY1: 1개 마스킹
#   DY2: 2개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 56 (총 마스킹 수: 7):
#   BY1: 3개 마스킹
#   DY1: 3개 마스킹
#   DY2: 1개 마스킹
#
# Inspection ID 57 (총 마스킹 수: 7):
#   BY1: 3개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY3: 2개 마스킹
#
# Inspection ID 58 (총 마스킹 수: 4):
#   AX1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 59 (총 마스킹 수: 6):
#   BY1: 2개 마스킹
#   DY2: 3개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 60 (총 마스킹 수: 5):
#   BY1: 2개 마스킹
#   CY1: 2개 마스킹
#   DY3: 1개 마스킹
#
# Inspection ID 61 (총 마스킹 수: 4):
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 62 (총 마스킹 수: 10):
#   BY1: 3개 마스킹
#   DY1: 2개 마스킹
#   DY2: 1개 마스킹
#   DY3: 3개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 63 (총 마스킹 수: 3):
#   AX1: 1개 마스킹
#   BY1: 1개 마스킹
#   DY1: 1개 마스킹
#
# Inspection ID 64 (총 마스킹 수: 9):
#   AX1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 5개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 66 (총 마스킹 수: 9):
#   BY1: 3개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY3: 1개 마스킹
#   DY4: 3개 마스킹
#
# Inspection ID 67 (총 마스킹 수: 13):
#   BY1: 2개 마스킹
#   CY1: 3개 마스킹
#   DY1: 2개 마스킹
#   DY2: 4개 마스킹
#   DY3: 1개 마스킹
#   DY4: 1개 마스킹
#
# Inspection ID 68 (총 마스킹 수: 18):
#   AX1: 1개 마스킹
#   BY1: 3개 마스킹
#   CY1: 2개 마스킹
#   DY1: 3개 마스킹
#   DY2: 2개 마스킹
#   DY3: 3개 마스킹
#   DY4: 4개 마스킹
#
# Inspection ID 69 (총 마스킹 수: 14):
#   AX1: 1개 마스킹
#   BY1: 3개 마스킹
#   CY1: 1개 마스킹
#   DY1: 4개 마스킹
#   DY2: 3개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 70 (총 마스킹 수: 5):
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY3: 1개 마스킹
#
# Inspection ID 71 (총 마스킹 수: 9):
#   CY1: 2개 마스킹
#   DY1: 1개 마스킹
#   DY2: 3개 마스킹
#   DY3: 1개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 72 (총 마스킹 수: 15):
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#   DY1: 3개 마스킹
#   DY2: 5개 마스킹
#   DY3: 1개 마스킹
#   DY4: 3개 마스킹
#
# Inspection ID 73 (총 마스킹 수: 11):
#   DY1: 3개 마스킹
#   DY2: 6개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 74 (총 마스킹 수: 11):
#   BY1: 5개 마스킹
#   CY1: 1개 마스킹
#   DY2: 1개 마스킹
#   DY3: 2개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 75 (총 마스킹 수: 5):
#   BY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 2개 마스킹
#   DY3: 1개 마스킹
#
# Inspection ID 76 (총 마스킹 수: 12):
#   BY1: 6개 마스킹
#   DY1: 1개 마스킹
#   DY3: 3개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 77 (총 마스킹 수: 6):
#   CY1: 1개 마스킹
#   DY1: 3개 마스킹
#   DY2: 1개 마스킹
#   DY3: 1개 마스킹
#
# Inspection ID 78 (총 마스킹 수: 9):
#   BY1: 2개 마스킹
#   CY1: 1개 마스킹
#   DY1: 2개 마스킹
#   DY3: 2개 마스킹
#   DY4: 2개 마스킹
#
# Inspection ID 79 (총 마스킹 수: 4):
#   BY1: 1개 마스킹
#   CY1: 1개 마스킹
#   DY1: 1개 마스킹
#   DY2: 1개 마스킹
#
# === 마스킹 통계 요약 ===
# 완전한 데이터 중 마스킹이 적용된 inspection_id: 74개
# 마스킹이 적용되지 않은 inspection_id: 0개
#
# 카테고리별 마스킹 적용된 inspection_id 수:
#   AX1: 23개 inspection_id에서 마스킹
#   BY1: 62개 inspection_id에서 마스킹
#   CY1: 43개 inspection_id에서 마스킹
#   DY1: 57개 inspection_id에서 마스킹
#   DY2: 56개 inspection_id에서 마스킹
#   DY3: 49개 inspection_id에서 마스킹
#   DY4: 58개 inspection_id에서 마스킹
#
# === 최종 요약 ===
# 전체 inspection_id: 86개
#   - 완전한 데이터 (21장): 74개
#     - 정상품 (7개 구멍 모두 존재): 74개
#     - 결함품 (일부 구멍 누락): 0개
#   - 불완전한 데이터 (21장 미만): 12개 → 분석 제외 권장
#
# 완전한 데이터 inspection_id들의 통계:
# 존재하는 카테고리 수 분포:
# existing_count
# 7    74
# Name: count, dtype: int64

# %% [markdown]
# ### 📌 real_labeled_test_set_masked_images 데이터의 특성
# - 모든 완전한 데이터(74개 inspection_id)에서 7개 카테고리가 모두 존재
# - 하지만 모든 inspection_id에서 마스킹이 적용됨 (74개 모두)
# - 즉, 마스킹 = 결함 시뮬레이션이 모든 제품에 적용된 테스트 데이터셋
# - 마스킹된 어노테이션들이 바로 YOLO 모델이 찾지 못해야 하는 결함
#
# ### 📌 마스킹 패턴 분석
# - BY1이 가장 자주 마스킹됨 (62개 inspection_id)
# - AX1이 가장 적게 마스킹됨 (23개 inspection_id)
# - 각 inspection_id당 평균 약 8-9개의 어노테이션이 마스킹
